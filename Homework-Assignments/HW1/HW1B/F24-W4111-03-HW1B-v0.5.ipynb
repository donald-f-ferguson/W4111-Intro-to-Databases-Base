# %% [markdown]
# # F24-W4111-03 -- Introduction to Databases: Homework 1, Part B

# %% [markdown]
# ## Submission Instructions

# %% [markdown]
# ## Environment Setup

# %%
# %pip install pandas
import pandas

# %%
import sqlalchemy

# %%
import pymysql

# %%
import json

# %%
# %load_ext sql

# %%
# %sql mysql+pymysql://root:dbuserdbuser@localhost

# %%
engine = sqlalchemy.create_engine("mysql+pymysql://root:dbuserdbuser@localhost")

# %% [markdown]
# ## Entity Relationship Modeling

# %% [markdown]
# ### Top-Down Modeling

# %% [markdown]
# The ability to prduce an ER diagram for a "human" description of the data model is an import skill. In this process, you may have to make and document assumptions or explain decisions. As long as your assumptions and decisions are reasonable, and your model accurately reflects in the notation that requirements, your model is "just enough modeling."

# %% [markdown]
# In this scenario, there are four entity types/sets:
# 1. _Person,_ represents basic information about a person. The type has properties/attributes:
#    - id uniquely indentifies the Person
#    - last_name
#    - first_name
#    - middle_name
#    - created_timestamp: When the the entity was created for the first time.
#    - last_modified_timestamp: The last time the entity's information changed.
# 2. _Contact Information_ represents a mechanism for contacting a person.
#    - There are two types of contact: phone, email.
#    - The value for the contact is simply a text string for both types of contact.
# 4. _Order,_ represents someone having placed an order to purchase something. Order has the properties:
#    - A unique order_number
#    - The date the order was placed
#    - A text description of the order
# 6. _Comment_ represent a user's comment on an order. Comment has two properties:
#    - Text of the comment
#    - Timestamp when the comment was made.

# %% [markdown]
# The model has the following relationships:
# - _Person-Comment_ is a relationship the represents the fact that the user made the comment. A user may make many comments, but a comment is made by only one user.
# - _Order-Comment_ associates the Comment with the Order. There may be many comments on an order but a comment has one order.
# - _Person-Contact-Info_ is between Person and Contact-Info. A Person may have multiple Contact-Info entries. A Contact-Info is relates to only one user.
#
# The model must represent the fact that Contact-Info is valid between a start timestamp and end timestamp.
#
# The system never deletes any information.

# %% [markdown]
# You must create a Crow's Foot Notation _logic model_ that is your model that satisfies the requirements. You may have to add unspecified attributes to entity types.

# %% [markdown]
# Show your diagram below. You can add notes to your diagram or add explanatory text.
#
# There is no single correct answer.

# %% [markdown]
# Digram:
# <hr><br><br><br>
#
#
# <hr>

# %% [markdown]
# ### Implement ER Diagram

# %% [markdown]
# <img src='er-to-sql.jpg'>

# %% [markdown]
# Write SQL DDL that creates the tables and relationships in the preceding diagram
#
# You can pick ```VARCHAR(32)``` for the type of each column.
#
# You must specify keys and foreign keys.
#
# Create a new database that you name ```hw1b_<uni>``` and replace ```<uni>``` with your UNI. For example, mine would be ```hw1b_dff9.```
#
#
# You must enter and successfully execute your SQL in the code cell below.

# %%
# %%sql
#
# /* Your create and alter table statements. */
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %% [markdown]
# ## Relational Algebra

# %% [markdown]
# You will use the Relax calulator and the schema associated with the text book for this question.
#
# https://dbis-uibk.github.io/relax/calc/gist/4f7866c17624ca9dfa85ed2482078be8/relax-silberschatz-english.txt/0

# %% [markdown]
# ### Problem 1

# %% [markdown]
# Write a relational algebra expression that produces a result table with the following format:
#
# ```(student_id, student_name, course_title, course_id, sec_id, semester, year, instructor_id, instructor_name)```

# %% [markdown]
# - student_id is a student's ID (```student.ID```)
# - student_name is a student's name (```student.name```)
# - course_title (```course.title```)
# - The following columns are common to ```section, takes, teaches:```
#     - course_id
#     - sec_id,
#     - semester
#     - year
# - instructor_id is an instructor's ID (```instructor.ID```)
# - instructor_name is an instructor's name (```instructor.name```)
#
# This derived relation represents student that took a section and the instructor taught the section.
#
# Cut and paste your query in the markdown cell below.

# %% [markdown]
# Past relational algebra here.

# %% [markdown]
# Execute your query on the Relax calculator and show an image of the first page of your result below.

# %% [markdown]
# ### Problem 2

# %% [markdown]
# Write a relational algebra expression that produces a result table with the following format:
#
# ```(dept_name, building, classroom, capacity)```
#
# This contains tuples where:
# - The department is in the building, e.g. there is a tuples in ```department``` that has the dept_name and building.
# - The classroom is in the building.
# - The result ONLY contains entries for which the department's budget is greather than 100,000 or the classroom's capacity is greater than 100.

# %% [markdown]
# Past relational algebra here.

# %% [markdown]
# Execute your query on the Relax calculator and show an image of the first page of your result below.

# %% [markdown]
# ## SQL

# %% [markdown]
# Use the database that is associated with the recommended textbook for these questions.

# %% [markdown]
# ### Problem 1

# %% [markdown]
# Write a SQL query that produces the same result as the relational algebra in Problem 1 above. Execute your SQL below.

# %%
# %%sql

# %% [markdown]
# ### Problem 2

# %% [markdown]
# Write a SQL query that produces the same result as the relational algebra in Problem 1 above. Execute your SQL below.

# %%
# %%sql

# %% [markdown]
# # TAs-Please Ignore the Below for Now

# %% [markdown]
# ## Introduction and Context

# %% [markdown]
# <img src="data_engineering.jpg" width="900px;">

# %% [markdown]
# <img src="overall_system.jpg" width="900px;">

# %% [markdown]
# ## Environment

# %% [markdown]
# ## Load Some Data

# %%
data_file = "./lor_characters.json"
with open(data_file, "r") as in_file:
    person_data = json.load(in_file)

# %%
person_data
# Out:
# [{'character': 'Frodo Baggins',
#   'book': 'The Fellowship of the Ring',
#   'chapter_location': 'Chapter 1: A Long-expected Party',
#   'geographical_location': 'The Shire',
#   'description': 'Frodo inherits the One Ring from Bilbo during his birthday celebration.'},
#  {'character': 'Frodo Baggins',
#   'book': 'The Two Towers',
#   'chapter_location': 'Book 4, Chapter 1: The Taming of Sméagol',
#   'geographical_location': 'Emyn Muil',
#   'description': 'Frodo continues his journey with Sam and captures Gollum as they traverse the rocky Emyn Muil.'},
#  {'character': 'Frodo Baggins',
#   'book': 'The Return of the King',
#   'chapter_location': 'Book 6, Chapter 1: The Tower of Cirith Ungol',
#   'geographical_location': 'Cirith Ungol, Mordor',
#   'description': 'Frodo is imprisoned in the tower, and Sam plans to rescue him in the land of Mordor.'},
#  {'character': 'Samwise Gamgee',
#   'book': 'The Fellowship of the Ring',
# ...

# %%
data_file = "./lor_character_interactions.json"
with open(data_file, "r") as in_file:
    person_interactions = json.load(in_file)

# %%
person_interactions
# Out:
# [{'character_1': 'Frodo Baggins',
#   'interaction_type': 'gives the ring to',
#   'character_2': 'Gandalf',
#   'book': 'The Fellowship of the Ring',
#   'chapter': 'Chapter 2: The Shadow of the Past',
#   'location': 'Bag End, The Shire'},
#  {'character_1': 'Aragorn',
#   'interaction_type': 'guides',
#   'character_2': 'Frodo Baggins',
#   'book': 'The Fellowship of the Ring',
#   'chapter': 'Chapter 10: Strider',
#   'location': 'Bree, Eriador'},
#  {'character_1': 'Gandalf',
#   'interaction_type': 'fights',
#   'character_2': 'Balrog',
#   'book': 'The Fellowship of the Ring',
#   'chapter': 'Chapter 5: The Bridge of Khazad-dûm',
#   'location': 'Moria'},
#  {'character_1': 'Legolas',
#   'interaction_type': 'befriends',
#   'character_2': 'Gimli',
#   'book': 'The Two Towers',
#   'chapter': 'Chapter 5: The White Rider',
#   'location': 'Fangorn Forest'},
#  {'character_1': 'Éowyn',
#   'interaction_type': 'kills',
#   'character_2': 'Witch-king of Angmar',
# ...

# %%
characters_df = pandas.DataFrame(person_data)

# %%
characters_df
# Out:
#          character                        book  \
# 0    Frodo Baggins  The Fellowship of the Ring
# 1    Frodo Baggins              The Two Towers
# 2    Frodo Baggins      The Return of the King
# 3   Samwise Gamgee  The Fellowship of the Ring
# 4   Samwise Gamgee      The Return of the King
# 5          Aragorn  The Fellowship of the Ring
# 6          Aragorn              The Two Towers
# 7          Aragorn      The Return of the King
# 8          Gandalf  The Fellowship of the Ring
# 9          Gandalf              The Two Towers
# 10         Legolas  The Fellowship of the Ring
# 11           Gimli  The Fellowship of the Ring
# 12         Boromir  The Fellowship of the Ring
# 13          Gollum              The Two Towers
# 14         Saruman              The Two Towers
# 15       Galadriel  The Fellowship of the Ring
# 16          Elrond  The Fellowship of the Ring
# 17           Éowyn              The Two Towers
# 18           Éomer              The Two Towers
# ...

# %%
interactions_df = pandas.DataFrame(person_interactions)

# %%
interactions_df
# Out:
#          character_1        interaction_type  \
# 0      Frodo Baggins       gives the ring to
# 1            Aragorn                  guides
# 2            Gandalf                  fights
# 3            Legolas               befriends
# 4              Éowyn                   kills
# 5      Frodo Baggins             argues with
# 6     Samwise Gamgee                   saves
# 7      Frodo Baggins          shows mercy to
# 8            Aragorn  claims allegiance from
# 9   Merry Brandybuck  rides into battle with
# 10           Saruman                 betrays
# 11            Gollum     bites the finger of
# 12           Aragorn                  crowns
# 13     Frodo Baggins                 rescues
# 14       Pippin Took        swears fealty to
# 15     Frodo Baggins          is betrayed by
# 16           Faramir                captures
# 17           Aragorn           is crowned by
# 18            Gollum                  guides
# 19           Gandalf                 rescues
# ...

# %% [markdown]
# ## Save Some Data

# %%
# %sql create database  if not exists lor_data;
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# []

# %%
characters_df.to_sql(
    "characters_raw",
    schema="lor_data",
    con=engine,
    index=False,
    if_exists="replace"
)
# Out:
# 22

# %%
characters_df.to_sql(
    "interactions_raw",
    schema="lor_data",
    con=engine,
    index=False,
    if_exists="replace"
)
# Out:
# 22

# %%
# %sql use lor_data;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %%
# %sql select * from characters_raw;
# Out:
#  * mysql+pymysql://root:***@localhost
# 22 rows affected.
# [('Frodo Baggins', 'The Fellowship of the Ring', 'Chapter 1: A Long-expected Party', 'The Shire', 'Frodo inherits the One Ring from Bilbo during his birthday celebration.'),
#  ('Frodo Baggins', 'The Two Towers', 'Book 4, Chapter 1: The Taming of Sméagol', 'Emyn Muil', 'Frodo continues his journey with Sam and captures Gollum as they traverse the rocky Emyn Muil.'),
#  ('Frodo Baggins', 'The Return of the King', 'Book 6, Chapter 1: The Tower of Cirith Ungol', 'Cirith Ungol, Mordor', 'Frodo is imprisoned in the tower, and Sam plans to rescue him in the land of Mordor.'),
#  ('Samwise Gamgee', 'The Fellowship of the Ring', 'Chapter 3: Three is Company', 'The Shire', 'Sam leaves the Shire with Frodo and begins their journey through the woods towards Bree.'),
# ...

# %% [markdown]
# ## Do Some Analysis

# %%
# %sql select count(*) as no_of_entries from characters_raw;
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# [(22,)]

# %%
# %%sql
#
# select `character`, count(*) as no_of_entries from characters_raw group by `character`;
# Out:
#  * mysql+pymysql://root:***@localhost
# 16 rows affected.
# [('Frodo Baggins', 3),
#  ('Samwise Gamgee', 2),
#  ('Aragorn', 3),
#  ('Gandalf', 2),
#  ('Legolas', 1),
#  ('Gimli', 1),
#  ('Boromir', 1),
#  ('Gollum', 1),
#  ('Saruman', 1),
#  ('Galadriel', 1),
#  ('Elrond', 1),
#  ('Éowyn', 1),
#  ('Éomer', 1),
#  ('Théoden', 1),
#  ('Faramir', 1),
#  ('Treebeard', 1)]

# %%
# %sql select geographical_location, count(*) as no_of_entries from `characters_raw` group by geographical_location;
# Out:
#  * mysql+pymysql://root:***@localhost
# 13 rows affected.
# [('The Shire', 3),
#  ('Emyn Muil', 2),
#  ('Cirith Ungol, Mordor', 2),
#  ('Bree', 1),
#  ('Amon Hen, near the Anduin River', 1),
#  ('Paths of the Dead', 1),
#  ('Fangorn Forest', 2),
#  ('Rivendell', 4),
#  ('Orthanc, Isengard', 1),
#  ('Lothlórien', 1),
#  ('Edoras, Rohan', 2),
#  ('Rohan', 1),
#  ('Ithilien', 1)]

# %% [markdown]
# Character is a reserved word in SQL. So, I am going to change it.

# %%
# %%sql
#
# use lor_data;
#
# alter table characters_raw
#     change `character` character_name text null;
#
# alter table interactions_raw
#     change `character` character_name text null;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %sql select * from characters_raw;
# Out:
#  * mysql+pymysql://root:***@localhost
# 22 rows affected.
# [('Frodo Baggins', 'The Fellowship of the Ring', 'Chapter 1: A Long-expected Party', 'The Shire', 'Frodo inherits the One Ring from Bilbo during his birthday celebration.'),
#  ('Frodo Baggins', 'The Two Towers', 'Book 4, Chapter 1: The Taming of Sméagol', 'Emyn Muil', 'Frodo continues his journey with Sam and captures Gollum as they traverse the rocky Emyn Muil.'),
#  ('Frodo Baggins', 'The Return of the King', 'Book 6, Chapter 1: The Tower of Cirith Ungol', 'Cirith Ungol, Mordor', 'Frodo is imprisoned in the tower, and Sam plans to rescue him in the land of Mordor.'),
#  ('Samwise Gamgee', 'The Fellowship of the Ring', 'Chapter 3: Three is Company', 'The Shire', 'Sam leaves the Shire with Frodo and begins their journey through the woods towards Bree.'),
# ...

# %%
# %%sql
#
# with one as (select
#         book as main_book,
#         chapter_location,
#     substr(chapter_location, 1, locate(',', chapter_location)-1) as sub_book,
#     substr(chapter_location, locate(',', chapter_location)+1) as the_rest
# from
#     characters_raw),
# two as (select
#     main_book,
#     if(sub_book = '', 'Book 1', sub_book) as sub_book,
#     substr(the_rest, 1, locate(':', the_rest)-1) chapter_no,
#     substr(the_rest, locate(':', the_rest)+1) chapter_title
# from
#     one)
# select
#     main_book,
#     substr(sub_book, 6) as sub_book_no,
#     substr(trim(chapter_no), length('Chapter ')+1) as chapter_no,
#     chapter_title
# from
#     two;
# Out:
#  * mysql+pymysql://root:***@localhost
# 22 rows affected.
# [('The Fellowship of the Ring', '1', '1', ' A Long-expected Party'),
#  ('The Two Towers', '4', '1', ' The Taming of Sméagol'),
#  ('The Return of the King', '6', '1', ' The Tower of Cirith Ungol'),
#  ('The Fellowship of the Ring', '1', '3', ' Three is Company'),
#  ('The Return of the King', '6', '1', ' The Tower of Cirith Ungol'),
#  ('The Fellowship of the Ring', '1', '10', ' Strider'),
#  ('The Two Towers', '3', '1', ' The Departure of Boromir'),
#  ('The Return of the King', '5', '2', ' The Passing of the Grey Company'),
#  ('The Fellowship of the Ring', '1', '2', ' The Shadow of the Past'),
#  ('The Two Towers', '3', '5', ' The White Rider'),
#  ('The Fellowship of the Ring', '2', '3', ' The Ring Goes South'),
#  ('The Fellowship of the Ring', '2', '3', ' The Ring Goes South'),
#  ('The Fellowship of the Ring', '2', '2', ' The Council of Elrond'),
#  ('The Two Towers', '4', '1', ' The Taming of Sméagol'),
# ...
